# %% [markdown]
# #

# %% [markdown]
# # <center> Decision Tree

# %% [markdown]
# ## References
#
# * Hands-on Machine Learning with Scikit-Learn, Keras, and TensorFlow - Aurélien Géron
# * Machine learning - Fast reference guide - Matt Harrison
# * https://www.youtube.com/@patloeber
# * https://www.youtube.com/@Dataquestio
# * https://medium.com/turing-talks/turing-talks-17-modelos-de-predi%C3%A7%C3%A3o-decision-tree-610aa484cb05

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Definition
#
# A Decision Tree is a supervised learning model capable of handling both classification and regression tasks.
#
# This model operates by segmenting the data using rules and decisions applied to the variables.
#
# Decision tree models act as decision-making guides, resembling flowcharts where each branch signifies a choice based on features or attributes. They function by breaking down a problem into smaller steps, where at each step, a decision is made based on specific characteristics. These decisions lead to various paths in the tree until reaching a conclusion or final outcome. You can think of it like navigating a family tree to identify individuals. Similarly, a decision tree guides decision-making by exploring all possibilities based on available data.
#
# In classification, the prediction is typically the most common class, which can also be presented as the probability or proportion of each class. In regression, the prediction is often the average or median of the observed values in the resulting subset.
#
# Conceptually, a decision tree comprises a root, branches, nodes, and leaves. The root and nodes represent the variables to be evaluated, branches denote admissible values or paths in the decision-making process, while leaves represent the outputs.

# %% [markdown]
# The Decision Tree uses a method called Greedy Search. This method aims to identify the best rules that capture the relationship between input and output data, maximizing each step without considering the others. In other words, it seeks the best local solution rather than a global one. The method utilizes measures such as:
#
# #### Entropy
# * A measure of data uncertainty.
# * Entropy varies between 0 and 1, and its function results in a concave curve with x ranging from 0 to 1. When the data distribution is 0.5, the entropy will be maximum, and when the distribution is concentrated at 0 or 1, the entropy will be minimum. Put differently, in a completely homogeneous sample, entropy is zero, while in a completely heterogeneous sample, entropy is one.
#
# #### Information Gain
# * Reduction of entropy.
# * The higher, the better.
#
#
# #### Gini Criterion
# * If we randomly select two items from a population, they must belong to the same class, and the probability of that is 1 if the population is pure;
# * Probability that two random items belong to the same class;
# * The lower, the better. The higher the concentration in a class, the lower the Gini criterion.

# %% [markdown]
# It is important for the decision tree to use a data purity criterion to select the variables of the nodes because it helps ensure that the splits made in the tree are as informative as possible. By choosing variables that result in purer nodes, where one class dominates in each branch, the tree can make more accurate predictions. If we do not consider data purity when selecting variables for the nodes, the tree may end up being too complex and have lower generalization capability.

# %% [markdown]
# ## Some Math

# %% [markdown]
# ### Information Gain
#
# #### $ entropy = -\sum_{i}^m p_{i}log_{2} p_{i} $
# #### $ GI = entropy_{father} - \sum peso_{son} . entropy_{son} $
#
#
# Onde:
# ####    $ peso = \frac{sample_{son}}{sample_{father}} $
#
#
# ### Gini Criterion
#
# #### $ CG(D) = 1 - \sum_{i=1}^m p_{i}^2 $
#
# Onde:
#    * $ D $ represents the data;
#    * $ p $ is the probability of classes in D that belong to class $C_i$.

# %% [markdown]
# ### Calculation Steps
#
# * Select the best variable among all to start the tree
#     * Calculate the Information Gain or Gini Index
#     * Determine the best threshold in case of continuous variable
# * Select the best variable among all to continue the tree
#     * Calculate the Information Gain or Gini Index
#     * Determine the best threshold in case of continuous variable
# * Repeat the process until completing the tree
#     * Until only one observation remains in the leaf, or
#     * Until all observations are in one leaf, or
#     * Until reaching the pre-established depth, or
#     * Determine the minimum number of data points for a node, even if impure. Equivalent to defining the minimum acceptable entropy.
#
# The definition of the threshold determines the split of data for continuous variables, in other words, it defines the rule of the node.

# %% [markdown]
# ---

# %% [markdown]
# # Classifier

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data

# %%
# Imports
from sklearn import datasets

# Load data
bc = datasets.load_breast_cancer()

# Define X and y
X, y = bc.data, bc.target

# Separate train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %% [markdown]
# ## From Scratch

# %%
from my_DecisionTree import my_DecisionTreeClassifier, accuracy

# %%
# Define model
clf = my_DecisionTreeClassifier()

# Fit model
clf.fit(X_train, y_train)

# Predictions
predictions = clf.predict(X_test)

# Accurracy
acc = accuracy(predictions, y_test)
print("Accuracy: %.3f%%" % (acc * 100.0))
# Out:
# Accuracy: 92.110%

# %% [markdown]
# ## From Sklearn

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
# Define model
clf = DecisionTreeClassifier()

# Fit model
clf.fit(X_train, y_train)

# Predictions
predictions = clf.predict(X_test)

#accuracy(predictions, y_test)
acc = clf.score(X_test, y_test)
print("Accuracy: %.3f%%" % (acc * 100.0))
# Out:
# Accuracy: 89.474%

# %%
# Define model
clf = DecisionTreeClassifier(max_depth = 2)

# Fit model
clf.fit(X_train, y_train)

# Predictions
predictions = clf.predict(X_test)

#accuracy(predictions, y_test)
acc = clf.score(X_test, y_test)
print("Accuracy: %.3f%%" % (acc * 100.0))
# Out:
# Accuracy: 91.228%

# %%
plt.figure(figsize=(15,7))
plot_tree(clf, filled=True, fontsize=12);

# %% [markdown]
# # Regressor

# %% [markdown]
# ## Data

# %%
# Load data
url = "https://raw.githubusercontent.com/FernandoSartorGH/data/main/housing.csv"
df = pd.read_csv(url)

# Define X and y
X, y = df.iloc[:,0:-1], df.iloc[:,-1]

# Separate train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %% [markdown]
# ## From Scratch

# %%
from my_DecisionTree import my_DecisionTreeRegressor, accuracy

# %%
# ---

# %% [markdown]
# ## From Sklearn

# %%
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor

# %%
# Define model
reg = DecisionTreeRegressor()

# Fit model
reg.fit(X_train, y_train)

# Predictions
predictions = reg.predict(X_test)

# Accuracy
r2 = reg.score(X_test, y_test)
print("r2: %.3f%%" % (r2 * 100.0))
# Out:
# r2: 84.914%

# %%
# Define model
reg = DecisionTreeRegressor(max_depth=2)

# Fit model
reg.fit(X_train, y_train)

# Predictions
predictions = reg.predict(X_test)

# Accuracy
r2 = reg.score(X_test, y_test)
print("r2: %.3f%%" % (r2 * 100.0))
# Out:
# r2: 71.311%

# %%
# PLot tree
plt.figure(figsize=(15,7))
plot_tree(reg, filled=True, fontsize=12);

# %% [markdown]
# ___

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data

# %%
# Imports
from sklearn import datasets

# Load data
df = pd.read_excel('play_tennis.xlsx')

for col in ['Outlook','Temp','Humidity','Windy']:
    df[col] = df[col].astype('category')

# %%
df
# Out:
#     Outlook  Temp  Humidity  Windy Play
# 0         0     0         0      1   No
# 1         0     0         0      0   No
# 2         1     0         0      1  Yes
# 3         0     0         0      1  Yes
# 4         0     1         1      1  Yes
# 5         0     1         1      0   No
# 6         1     1         1      0  Yes
# 7         0     0         0      1   No
# 8         0     1         1      1  Yes
# 9         0     0         1      1  Yes
# 10        0     0         1      0  Yes
# 11        1     0         0      0  Yes
# 12        1     0         1      1  Yes
# 13        0     0         0      0   No

# %%
from sklearn.preprocessing import LabelEncoder

for col in ['Outlook','Temp','Humidity','Windy']:
    X = df[col]

    # Fit
    le = LabelEncoder()
    le.fit(X)
    df[col] = le.transform(X)

# %%
# Define X and y
X, y = df[['Outlook','Temp','Humidity','Windy']], data.Play

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
# Define model
clf = DecisionTreeClassifier(criterion='entropy', max_depth=3)

# Fit model
clf.fit(X, y)

# Predictions
#predictions = clf.predict(X_test)

#accuracy(predictions, y_test)
#acc = clf.score(X_test, y_test)
#print("Accuracy: %.3f%%" % (acc * 100.0))
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
plt.figure(figsize=(15,7))
plot_tree(clf, filled=True, fontsize=12);
